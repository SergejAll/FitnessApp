# %% [markdown]
# <a href="https://colab.research.google.com/github/SergejAll/FitnessApp/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hw1: Exploring and Evaluating Word Embeddings (20 Points)
# This assignment aims to familiarize you with loading, manipulating, and evaluating pre-trained word embeddings using the gensim library and the SimLex-999 dataset.

# %% [markdown]
# Please run the following cell to install **gensim** library.
#
# Once the **gensim** library is installed, please re-activate the environment to ensure the code can run well.

# %%
# !pip install numpy==1.24.3 scipy==1.13.1 gensim==4.3.3

# %% [markdown]
# # **Task 1: Activation Funtion (3 Points)**

# %% [markdown]
# ## **Task 1.1 Implementing sigmoid and its derivative (1.5 Points)**

# %% [markdown]
# ### **Part A: Implementation (1 Point)**

# %%
import numpy as np

def sigmoid(x):
    """
    Computes the sigmoid activation for a given input x.

    Args:
        x (int, float, or np.ndarray): Scalar or array of numeric values.

    Returns:
        float or np.ndarray: Sigmoid of x.
    """

    # Your code here
    raise NotImplementedError

def sigmoid_derivative(x):
    """
    Computes the derivative of the sigmoid function.
    Uses the form: sigma(x) * (1 - sigma(x)).

    Args:
        x (float or np.ndarray): Input value or array
                                 (can be the original input to sigmoid,
                                  or the output of sigmoid itself if precomputed).

    Returns:
        float or np.ndarray: Derivative of sigmoid at x.
    """

    # Your code here
    raise NotImplementedError

# %% [markdown]
# ### **Part B: Testing (0.5 Points)**
# Calculate the sigmoid and derivative of **x_scalar** and **x_array** by calling your implemented function. Store your results in **sig_x_scalar**, **sig_x_array**, **derivative_x_scalar** and **derivative_x_array**, respectively. Print the corresponding results.

# %%
x_scalar = 0
x_array = np.array([-2.0, -1.0, 0.0, 1.0, 2.0])

# Your code here

# %% [markdown]
# ## **Task 1.2 Activation function in MLP (1.5 Points)**
# Consider a MLP designed for a binary classification task (e.g., sentiment analysis where output is positive/negative). The network has an input layer, one or more hidden layers, and a single neuron in the output layer. Answer the following questions:
#
# * (0.5 Points) Explain in your own words why non-linear activation functions are essential in hidden layers of an MLP. What would happen if all hidden layers only used a linear activation function (i.e., f(x) = x)
# * (0.5 Points) What is the output range of the Sigmoid function? How is this range particularly useful for the output neuron in a binary classification task?
# * (0.5 Points) Discuss at least two significant advantages of using ReLU in hidden layers compared to Sigmoid.

# %%
# Your answer here

# %% [markdown]
# # **Task 2: Different Word Embedding Models (17 Points)**

# %% [markdown]
# ## **Task 2.1: Setup**
#
# For this task, you will need:
# * the gensim python library: https://radimrehurek.com/gensim (included in the colab environment),
# * the binary pretrained 300-dimensional word2vec embeddings
# * the pretrained 100-dimensional glove embeddings
# * the pretrained 300-dimensional fasttext embeddings
# * the SimLex-999 data set: https://fh295.github.io/SimLex-999.zip, is an extension of WS353 which is a set of word pairs along with their similarity that is derived from human ratings.

# %% [markdown]
# ## **Task 2.2: Loadinng Models and Vector Retrieval (4.5 Points)**

# %% [markdown]
# ### **Part A: Loading Models (0.5 Points)**
# Your first task is to load pre-trained word embedding models (specifically, a Word2cec model, a GloVe model and a FastText model) using the gensim library. Then, create a function to retrieve the vector representation for any given word from a loaded model. This function should gracefully handle cases where a word might not be present in the model's vocabulary (Out-of-Vocabulary or OOV words).
#
# Use **gensim.downloader** to load the 'word2vec-google-news-300' model, the 'glove-wiki-gigaword-100' model and the 'fasttext-wiki-news-subwords-300' model. Store the loaded models in variables (e.g., word2vec_model, glove_model, fasttext_model).

# %%
import gensim.downloader as api

WORD2VEC_MODEL_NAME = 'word2vec-google-news-300'
GLOVE_MODEL_NAME = 'glove-wiki-gigaword-100'
FASTTEXT_MODEL_NAME = 'fasttext-wiki-news-subwords-300'

try:
    # Your code here
    print(f"Word2vec Model ('{WORD2VEC_MODEL_NAME}') loaded successfully!")
except FileNotFoundError:
    print(f"Error: Model file '{WORD2VEC_MODEL_NAME}' not found. Please ensure the path is correct and the file is extracted.")
    word2vec_model = None
except Exception as e:
    print(f"An error occurred while loading the model: {e}")
    word2vec_model = None
try:
    # Your code here
    print(f"GloVe model ('{GLOVE_MODEL_NAME}') loaded successfully!")
except Exception as e:
    print(f"Error loading GloVe model ('{GLOVE_MODEL_NAME}'): {e}")
    glove_model = None

try:
    # Your code here
    print(f"FastText model ('{FASTTEXT_MODEL_NAME}') loaded successfully!")
except Exception as e:
    print(f"Error loading FastText model ('{FASTTEXT_MODEL_NAME}'): {e}")

# %% [markdown]
# ### **Part B: Vector Retrieval (1 Point)**
# Implement a Python function **get_word_vector(word, model)** that takes a word (string) and a loaded gensim model object as input.
# If the word exists in the model's vocabulary, return its corresponding vector (NumPy array).
# If the word does not exist, return None.
#
# Hint: Use a try-except KeyError block inside **get_word_vector(word, model)** to handle OOV words

# %%
def get_word_vector(word, model):
    """
    Retrieves the word vector for a given word.

    Args:
    word (str): The word to query.
    model : The loaded word2vec, glove and fasttext model.

    Returns:
    numpy.ndarray: The word vector for the word, or None if the word is not found.
    """
    # Your code here
    raise NotImplementedError

# %% [markdown]
# ### **Part C: Testing (3 Points)**
# (1.5 Points) Test your **get_word_vector(word, model)** function with all three loaded models. Query the vectors for the words: "cat", "democracy" and "daojfdlakfj". Print the shape of the retrieved vectors and the first 2 dimensions to verify.
# Store the result separately in:
# * First 2 dimensions of retrived vectors: **vector_word2vec**, **vector_glove**, **vector_fasttext**. Each should be a list, containing the first two dimension of the corresponding vector representations. e.g. [array([ 0.1, 0.2], dtype=float32), array([ 0.3, 0.4], dtype=float32), array([0.5, 0.6], dtype=float32)]. The first array is vector representation for first word, second array for second word, third array for third word.
# * Shape of retrived vectors: **shape_word2vec**, **shape_glove**, **shape_fasttext**. Each should be a list, containing the dimensions of corresponding vector representations of a specific model. e.g. [(10,), (20,), (30)]
#
# (0.5 Point) Try to explain why you cannot find the third word in 1-2 sentences.

# %%
# each correct assert function = 0.5 pt
if word2vec_model and glove_model and fasttext_model:
    words_to_query= ["cat", "democracy", "daojfdlakfj"]

    vector_word2vec = []
    vector_glove = []
    vector_fasttext = []
    shape_word2vec = []
    shape_glove = []
    shape_fasttext = []

    # Your code here

# %% [markdown]
# (1 Point) Please find a real word (not random sequence of letters) that is not in any of these 3 models.

# %%
# Your code here

# %% [markdown]
# ## **Task 2.3: Measuring Semantic Similarity (2 Points)**
# Word embeddings place words with similar meanings closer together in the vector space. A common way to measure this closeness is using cosine similarity. Implement a function to calculate cosine similarity and apply it to word pairs using the models loaded in Task 1.2.

# %% [markdown]
# ### **Part A: Cosine Similarity Function (0.5 Points)**
# Implement a Python function cosine_similarity(vec1, vec2) that takes two vectors (NumPy arrays) as input and returns their cosine similarity (a float between -1 and 1). Handle potential division by zero if either vector has zero magnitude (return 0.0 in that case). The cosine similarity between two vectors $\mathbf{a}$ and $\mathbf{b}$ is given by:
#
# $\quad cos(\theta)=\frac{a * b}{\|a\|*\|b\|}$
#
# Hint: please do not use any built-in function in **gensim**

# %%
from numpy.linalg import norm

def cosine_similarity(vec1, vec2):
    """
    Calculates the cosine similarity between two vectors.

    Args:
    vec1 (numpy.ndarray): The first vector.
    vec2 (numpy.ndarray): The second vector.

    Returns:
    float: The cosine similarity between the two vectors. Returns None if either vector is None.
    """
    # Your code here
    raise NotImplementedError

# %% [markdown]
# ### **Part B: Testing (1.5 Points)**
# Using your **get_word_vector** function from Task 1.2 and the **cosine_similarity** function, calculate and print the cosine similarity for the following word pairs using all three models:
# * ("king", "queen")
# * ("car", "bike")
# * ("king", "cabbage")
#
# Please use built-in method in **gensim** to double check your result. Store your result separately in **similarity_w2v**, **gensim_similarity_w2v**, **similarity_glove**, **gensim_similarity_glove**, **similarity_fasttext**, **gensim_similarity_fasttext**. Each of them is a list the cosine similarity and the built-in method calculated similarity of the corresponding models based on the 3 word pairs. e.g.similarity_w2v = [0.111111, 0.222222, 0.333333].

# %%
word_pairs = [
    ("king", "queen"),
    ("car", "bike"),
    ("king", "cabbage")
        ]

# %%
# word2vec model
# Your code here

# %%
# GloVe model
# Your code here

# %%
# Fasttext model
# Your code here

# %% [markdown]
# ## **Task 2.4: Measuring Semantic Similarity (5 Points)**
#
# Word embeddings often capture relational similarities, allowing for word analogies like "man is to king as woman is to queen". Use the most_similar method available in gensim models to perform such analogies.

# %% [markdown]
# ### **Part A: Analogy Function (1 Point)**
# Implement a Python function solve_analogy(word1, word2, word3, model, top_n) that aims to find the word X that completes the analogy word1 : word2 :: X : word3 (often computed as vector(word1) - vector(word2) + vector(word3)). Use the **model.most_similar()** method. The function should return a list of (word, score) tuples. Handle cases where input words might not be suitable for the analogy operation in the model (e.g., not in the known keys).

# %%
def solve_analogy(word1, word2, word3, model, top_n):
    """
    Solves word analogy problems: word1 - word2 + word3 = result

    Args:
    word1 (str): The first word
    word2 (str): The second word
    word3 (str): The third word
    model (gensim.models.KeyedVectors): The loaded word2vec model.
    top_n (int): The number of top similar results to return.

    Returns:
    list: A list of (word, similarity_score) tuples. Returns an empty list if OOV or error.
    """
    # Your code here
    raise NotImplementedError

# %% [markdown]
# ### **Part B: Testing 1 (1.5 Points)**
# Test your **solve_analogy** function with all three models for the following analogies (request the top 3 results, i.e., top_n=3):
# * man : king :: woman : ?
# * france : paris :: berlin : ?
# * sushi : japan :: germany : ?
#
# Please store your results model-wise in **results_w2v**, **results_glove**, **results_fasttext** separately. Each of them is a list of analogy results.
# Each element in the list corresponds to one analogy test (like "king - man + woman").

# %%
analogies_to_test = [
        ("king", "man", "woman"),
        ("france", "paris", "berlin"),
        ("sushi", "japan", "germany")
    ]

# %%
# word2vec model
# Your code here

# %%
# GloVe model
# Your code here

# %%
# Fasttext model
# Your code here

# %% [markdown]
# ### **Part C: Testing 2 (2 Points)**
# (1.5 Points)Test your **solve_analogy** function with all three models for the following analogies (request the top 3 results, i.e., top_n=3):
# * doctor : man :: woman : ?
# * housewife : woman :: man : ?
# * surgeon : man :: woman : ?
#
# Please store your results model-wise in **results_w2v_c**, **results_glove_c**, **results_fasttext_c** separately. Each of them is a list of analogy results.
# Each element in the list corresponds to one analogy test (like "king - man + woman").
#
# (0.5 Point) Shortly describe your insights based on your result.

# %%
analogies_to_test_c = [
        ("doctor", "man", "woman"),
        ("housewife", "woman", "man"),
        ("surgeon", "man", "woman")
    ]

# %%
# word2vec model
# Your code here

# %%
# GloVe model
# Your code here

# %%
# Fasttext model
# Your code here

# %%
# Your answer here

# %% [markdown]
# ### **Part D: Observations (0.5 Points)**
#
# Based on the cosine similarity and semantic similarity of all models, do they produce reasonable results? Are there differences? Discuss the potential reason based on the training algorithms and objectives.

# %%
# Your answer here

# %% [markdown]
# ## **Task 2.5: Processing the SimLex-999 Dataset (3 Points)**
# To evaluate how well our word embeddings capture human notions of similarity, we need to process a standard benchmark dataset like SimLex-999. This task involves reading the dataset file and calculating the model-predicted similarity for each valid word pair.

# %% [markdown]
# ### **Part A: Parsing Function (1.5 Points)**
# Implement a Python function parse_simlex(filepath, model) that takes the path to the SimLex-999 .txt file and a loaded gensim model as input.
# * Read the file (it's usually tab-separated, skip the header row).
# * For each row, extract word1, word2, and the SimLex999 score (human similarity). Remember to convert words to lowercase.
# * Use your get_word_vector function to get vectors for word1 and word2.
# * Use your cosine_similarity function to calculate the model's similarity score.
# * Only store pairs where both word1 and word2 have valid vectors in the provided model.
# Return a list where each element is a tuple: (word1, word2, human_similarity, model_similarity).
#
# Hint:
# * The SimLex-999 file typically has columns like word1, word2, POS, SimLex999, etc. Ensure you are extracting the correct column for the human similarity score.

# %%
import csv
from google.colab import files
SIMLEX_FILE = files.upload()
SIMLEX_FILE = ("./SimLex-999.txt")

def parse_simlex(filepath, model):
    """
    Parses the SimLex-999 dataset and calculates model-predicted similarities.

    Args:
    filepath (str): Path to the SimLex-999 data file.
    model (gensim.models.KeyedVectors): The loaded word2vec model.

    Returns:
    list: A list of (word1, word2, human_similarity, model_similarity) tuples.
          Only includes pairs where both words are in the model's vocabulary.
    """
    # Your code here
    raise NotImplementedError

# %% [markdown]
# ### **Part B: Testing (1.5 Points)**
# Call your **parse_simlex** function separately for all three models. Store the resulting lists (e.g., simlex_data_word2vec, simlex_data_glove, simlex_data_fasttext). Print the number of valid pairs processed for each model and display the first 2 entries from each list.
#
# Each of the list is a list of tuples, where each tuple is in a form of (word1, word2, human_similarity, model_similarity).

# %%
# word2vec model
# Your code here

# %%
# glove model
# Your code here

# %%
# fasttext model
# Your code here

# %% [markdown]
# ## **Task 2.6: Evaluating Embeddings with Spearman Correlation (2.5 Points)**
# Now that you have processed the SimLex-999 data and obtained both human and model similarity scores for valid word pairs, you can quantitatively evaluate the models using Spearman's rank correlation coefficient. This coefficient measures how well the ranking of pairs according to the model matches the ranking according to human judgment.

# %% [markdown]
# ### **Part A: Evaluation Function (1 Point)**
# Implement a Python function **evaluate_on_simlex(similarity_data_list)** that takes the list generated by **parse_simlex (e.g., simlex_data_glove)** as input.
# * Extract two lists from the input: one containing all human_similarity scores and one containing all corresponding model_similarity scores.
# * Use **scipy.stats.spearmanr to calculate** the Spearman correlation between these two lists.
# * Return the correlation coefficient and the p-value. Handle cases with insufficient data points (Spearman calculation requires at least 2 pairs).

# %%
from scipy.stats import spearmanr

# Function Definition - evaluate_embeddings_on_simlex (Question 5)
def evaluate_embeddings_on_simlex(similarity_data_list):
    """
    Evaluates word embeddings on SimLex-999 using Spearman correlation.

    Args:
    similarity_data_list (list): The list returned by the parse_simlex function.

    Returns:
    tuple: (spearman_coefficient, p_value). Returns (None, None) if data is insufficient.
    """
    # Your code here
    raise NotImplementedError

# %% [markdown]
# ### **Part B: Testing (1 point)**
# Call your **evaluate_on_simlex** function on the **simlex_data_word2vec**, **simlex_data_glove** and **simlex_data_fasttext** lists obtained in Task 1.5. Store the result separately in **spearman_coeff_word2vec**, **p_val_word2vec**, **spearman_coeff_glove**, **p_val_glove**, **spearman_coeff_fasttext**, **p_val_fasttext**. Print the Spearman correlation coefficient and p-value for all models

# %%
# word2vec model
# Your code here

# %%
# glove model
# Your code here

# %%
# fasttext model
# Your code here

# %% [markdown]
# ### **Part C: Conclusion (0.5 points)**
# Based on your results of Spearman coefficient and P-value, please describe your thoughts.

# %%
# Your answer here
